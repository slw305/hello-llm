# %% [markdown]
# #ChatPromptTemplate——把提示词变成模板

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_deepseek import ChatDeepSeek
from dotenv import load_dotenv
import os

load_dotenv()

prompt = ChatPromptTemplate.from_messages([
    ("system","你是一个{role},回答要简洁"),
    ("user","{question}")
])

#填充变量：invoke传字典

msg = prompt.invoke({"role":"Agent开发导师","question":"FastAPI为什么适合agent开发？"})
print(msg.to_messages())

llm = ChatDeepSeek(
    model="deepseek-v4-flash",
    api_key=os.getenv("DEEPSEEK_API_KEY"),
    temperature=0.5,
    max_tokens=500
)

resp = llm.invoke(msg)

print(resp.content)
# Out:
# [SystemMessage(content='你是一个Agent开发导师,回答要简洁', additional_kwargs={}, response_metadata={}), HumanMessage(content='FastAPI为什么适合agent开发？', additional_kwargs={}, response_metadata={})]
# FastAPI非常适合Agent开发，核心原因有以下几点：
#
# ## 1. **原生异步支持（最关键）**
# - Agent需要同时调用多个工具、LLM、数据库，天然是I/O密集型
# - FastAPI的async/await让你轻松并发执行多个工具调用，大幅提升吞吐量
# - 相比Flask/Django，避免阻塞事件循环
#
# ## 2. **流式输出友好**
# - 支持SSE（Server-Sent Events）和WebSocket
# - 实现LLM的token流式返回（打字机效果）非常简单
# - 这是Agent交互体验的刚需
#
# ## 3. **Pydantic提供工具Schema校验**
# - Agent的工具（Function Calling）需要定义输入/输出结构
# - Pydantic自动生成JSON Schema，直接喂给LLM作为tool定义
# - 输入校验、类型安全，减少工具调用出错
#
# ## 4. **自动生成OpenAPI文档**
# - 每个Agent API自动有Swagger UI
# - 方便调试、测试、给前端联调
# - 甚至可以把自己的API文档作为context给LLM做Agent自描述
#
# ## 5. **WebSocket内置支持**
# - Agent需要长连接（多轮对话、状态推送、实时交互）
# - FastAPI原生处理WebSocket，不用额外集成
#
# ## 6. **轻量灵活**
# - Agent架构经常快速迭代，FastAPI无重框架束缚
# - 中间件、依赖注入体系清晰，适合模块化组装
#
# ---
#
# **一句话总结**：Agent是多并发、多工具、流式交互的异步应用，FastAPI天生就是为此设计的。
